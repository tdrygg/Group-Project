# %%
# %matplotlib notebook

# %%
#Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#create dataframe reference
df2018 = pd.read_csv('Project1CSV/Niceride 2010to2018/NR2018/data_2018.csv')
df2017 = pd.read_csv('Project1CSV/Niceride 2010to2018/NR2017/Nice_ride_trip_history_2017_season.csv')
df2016 = pd.read_csv('Project1CSV/Niceride 2010to2018/NR2016/Nice_ride_trip_history_2016_season.csv')
df2015 = pd.read_csv('Project1CSV/Niceride 2010to2018/NR2015/Nice_ride_trip_history_2015_season.csv')
df2014 = pd.read_csv('Project1CSV/Niceride 2010to2018/NR2014/Nice_ride_trip_history_2014_season.csv')
df2013 = pd.read_csv('Project1CSV/Niceride 2010to2018/NR2013/Nice_ride_trip_history_2013_season.csv')
df2012 = pd.read_csv('Project1CSV/Niceride 2010to2018/NR2012/Nice_ride_trip_history_2012_season.csv')
df2011 = pd.read_csv('Project1CSV/Niceride 2010to2018/NR2011/Nice_ride_trip_history_2011_season.csv')
df2010 = pd.read_csv('Project1CSV/Niceride 2010to2018/NR2010/Nice_ride_trip_history_2010_season.csv')
# Out:
# C:\Users\FantaPC\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (2,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\FantaPC\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (0,1,2,3,4,5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df2010.head()
# Out:
#         Start date       Start station  Start terminal         End date  \
# 0   6/10/2010 8:01  100 Main Street SE           30000   6/10/2010 8:01
# 1  6/10/2010 17:38  100 Main Street SE           30000  6/10/2010 17:54
# 2  6/10/2010 21:15  100 Main Street SE           30000  6/10/2010 21:27
# 3  6/11/2010 13:52  100 Main Street SE           30000  6/11/2010 14:42
# 4  6/11/2010 15:20  100 Main Street SE           30000  6/11/2010 16:11
#
#               End station  End terminal  Total duration (ms) Account type
# 0      100 Main Street SE       30000.0               8018.0       Casual
# 1              IDS Center       30042.0             963762.0       Casual
# 2  11th Street & Hennepin       30004.0             717079.0       Casual
# 3  Washington & 2nd Ave N       30021.0            2966016.0       Casual
# 4             Blegen Hall       30019.0            3040238.0       Casual

# %%
df2018.head()
# Out:
#    tripduration start_time end_time  start station id  \
# 0          2490    49:49.9  31:20.5              10.0
# 1           228    29:22.1  33:10.5              16.0
# 2            80    15:30.3  16:51.1              21.0
# 3           755    02:00.8  14:36.4              10.0
# 4           850    09:51.6  24:02.2              18.0
#
#           start station name  start station latitude  start station longitude  \
# 0           Midtown Exchange               44.948590               -93.260200
# 1  22nd Ave S & Franklin Ave               44.962930               -93.241042
# 2            Social Sciences               44.970639               -93.243552
# 3           Midtown Exchange               44.948590               -93.260200
# 4          Walker Art Center               44.967104               -93.289075
#
#    end station id                   end station name  end station latitude  \
# 0            45.0                Franklin & Portland             44.962841
# ...

# %%
usertype2010 = df2010["Account type"].value_counts()
usertype2010
# Out:
# Casual     52752
# Member     49045
# Unknown       54
# Name: Account type, dtype: int64

# %%
#Create Pie chart depicting total ridership per user type in 2010
usertype2010count = [52752, 49045]
labels2010 = ["Member", "Casual"]
colors2010 = ["orange", "lightblue"]
plt.subplots(1)
plt.pie(usertype2010count, labels = labels2010, colors = colors2010, autopct='%1.1f%%', shadow=True, startangle=90) 
plt.title("2010 User Type Count")
plt.show(1)
plt.savefig("../Group-Project/JustinCoImages/2010usertypecount.png")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
usertype2018 = df2018["usertype"].value_counts()
usertype2018
# Out:
# Casual    290947
# Member    121476
# Name: usertype, dtype: int64

# %%
#Create Pie chart depicting total ridership per user type in 2018
usertype2018count = [121476, 290947]
labels2018 = ["Member", "Casual"]
colors2018 = ["orange", "lightblue"]
plt.subplots(1)
plt.pie(usertype2018count, labels = labels2018, colors = colors2018, autopct='%1.1f%%', shadow=True, startangle=70) 
plt.title("2018 User Type Count")
plt.show()
plt.savefig("../Group-Project/JustinCoImages/2018usertypecount.png")
# Out:
# <img src="data:image/png;base64,..." width="639.5333333333333">

# %%
#Count total of user types (cumulative for 2018)
usertype =  (df2018["usertype"].value_counts() + df2010["Account type"].value_counts() 
            + df2011["Account type"].value_counts() + df2012["Account type"].value_counts() 
            + df2013["Account type"].value_counts() + df2014["Account type"].value_counts()
            + df2015["Account type"].value_counts() + df2016["Account type"].value_counts() 
            + df2017["Account type"].value_counts())
usertype
# Out:
# Casual     1415892.0
# Inconnu          NaN
# Member     1697909.0
# Unknown          NaN
# dtype: float64

# %%
#Create pie chart showing overall combined year totals
usertypecount = [1697909, 1415892]
labels = ["Member", "Casual"]
colors = ["orange", "lightblue"]
plt.subplots(1)
plt.pie(usertypecount, labels = labels, colors = colors, autopct='%1.1f%%', shadow=True, startangle=90) 
plt.title("Overall User Type Count\n"+"(Cumulative)")
plt.show()
plt.savefig("../Group-Project/JustinCoImages/Overallusertypecount.png")
# Out:
# <img src="data:image/png;base64,..." width="639.5333333333333">

# %%
biketype2018 = df2018["bike type"].value_counts()
biketype2018
# Out:
# Classic     398980
# Dockless     13443
# Name: bike type, dtype: int64

# %%
#Create pie chart to compare number of classic (docked) vs. dockless bikes for 2018
bikecount2018 = [398980, 13443]
bikelabels2018 = ["Docked", "Dockless"]
bikeexplode = (0.3, 0.0)
bikelabelcolors = ["orange", "lightblue"]
plt.subplots(1)
plt.pie(bikecount2018, labels = bikelabels2018, colors = bikelabelcolors, 
        autopct='%1.1f%%', shadow=True, explode = bikeexplode, startangle=20) 
plt.title ("Bike Types 2018")
plt.show()
plt.savefig("../Group-Project/JustinCoImages/2018BikeComparisoncount.png")
# Out:
# <img src="data:image/png;base64,..." width="639.5333333333333">
